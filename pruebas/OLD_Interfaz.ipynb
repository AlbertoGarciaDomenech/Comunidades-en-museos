# %%
## DEPENDENCIAS

# %%capture output
# !pip install nodejs
# !pip install ipywidgets
# !pip install jupyterlab_widgets
# !pip install widgetsnbextension
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# UsageError: Line magic function `%%capture` not found.

# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from os import listdir
from os.path import isfile, join


from src.SimilarityArtworks import *
from src.SimilarityUsers import *
from src.ArtworksMatrix import *
from src.UsersMatrix import *
from src.UsersClustering import *
from src.AverageUser import *

# %%
import inspect

def inner_classes_list(cls):
    return [cls_attribute.__name__ for cls_attribute in cls.__dict__.values()
            if inspect.isclass(cls_attribute)]
            # and issubclass(cls_attribute, SimilarityFunctionInterface)]

# %%
def elegirDatos(path, files):
  usersDropdown = widgets.Dropdown(
      options=files,
      value='Prado_users_emotions_OnePolarity.csv',
      description='Users:',
      disabled=False,
  )
  itemsDropdown = widgets.Dropdown(
      options=files,
      value='Prado_artworks_wikidata.csv',
      description='Items:',
      disabled=False,
  )
  return usersDropdown, itemsDropdown

def cargarDatos(path, usersDropdown, itemsDropdown):
  users = pd.read_csv(path + usersDropdown.value, index_col=0)
  artworks = pd.read_csv(path + itemsDropdown.value)
  users['positive'] = users['positive'].apply(eval)
  users['negative'] = users['negative'].apply(eval)
  users['mixed'] = users['mixed'].apply(eval)
  return users, artworks

def elegirSimilitudItems(path, files, artworks):
  functions = [None]
  functions.extend(inner_classes_list(SimilarityArtworks))

  dropdowns = {}
  for col in artworks.columns:
    dropdowns[col] = widgets.Dropdown(options=functions, value=None, description=col, disabled=False)

  colorDropdown = widgets.Dropdown(options=files, value=None, description='Colors', disabled=False)

  return dropdowns, colorDropdown

def elegirSimilitudUsers(path, files, users):
  functions = [None]
  functions.extend(inner_classes_list(SimilarityUsers))

  dropdowns = {}
  for col in users.columns:
    dropdowns[col] = widgets.Dropdown(options=functions, value=None, description=col, disabled=False)
  
  return dropdowns

def elegirPesosItems(atr_dropdowns, colorDropdown):
  floatTexts = {}
  colorFloatText = None
  for key, value in atr_dropdowns.items():
    if value.value is not None:
      floatTexts[key] = widgets.FloatText(value=0.3, description=key, disabled=False, step = 0.1)

  if colorDropdown.value is not None:
    colorFloatText = widgets.FloatText(value=0.3, description='Colors', disabled=False,step = 0.1)
    
  return floatTexts, colorFloatText

def elegirPesosUsers(atr_dropdowns):
  floatTexts = {}
  for key, value in atr_dropdowns.items():
    if value.value is not None:
      floatTexts[key] = widgets.FloatText(value=0.3, description=key, disabled=False, step = 0.1)
  
  demographicFloatText = widgets.FloatText(value=0.5, description='Demographic', disabled=False, step = 0.1)
  polarityFloatText = widgets.FloatText(value=0.5, description='Polarity', disabled=False, step = 0.1)
  
  return floatTexts, demographicFloatText, polarityFloatText

def calcularSimilitudItems(path, artworks, atr_dropdowns, float_texts):
  funcs = {x : None for x in artworks.columns}
  weights = {x : None for x in artworks.columns}

  for key, value in atr_dropdowns.items():
    funcs.update({key: value.value})

  for key, value in float_texts.items():
    weights.update({key: value.value})
  weights.update({'Colors': colorFloatText.value})

  AM = ArtworksMatrix(artworks, function_dict=funcs, weight_dict=weights, colors_path=path + colorDropdown.value)
  
  return AM.getSimilarityMatrix()

def calcularSimilitudUsers(path, users, artworks_sim, atr_dropdowns, float_texts, demographicFloatText, polarityFloatText):
  funcs = {x : None for x in users.columns}
  weights = {x : None for x in users.columns}

  for key, value in atr_dropdowns.items():
    funcs.update({key: value.value})

  for key, value in float_texts.items():
    weights.update({key: value.value})

  weights.update({'polarity' : polarityFloatText.value, 'demographic' : demographicFloatText.value})  
  
  UM = UsersMatrix(users, artworks_sim, function_dict=funcs, weight_dict=weights)
  
  return UM.getSimilarityMatrix()

def calcularClusters(users, users_sim):
  users_distance = 1 - users_sim
  labels = UsersClustering(users_sim).kMedoidsFromMatrix() ## DISTANCES (?)
  users_clustered = users.copy()
  users_clustered['cluster'] = labels
  return users_clustered

# %%
data_path = 'data/'
files = [f for f in listdir(data_path) if isfile(join(data_path, f))]

usersDropdown, itemsDropdown = elegirDatos(data_path, files)
display(itemsDropdown)
display(usersDropdown)
# Out:
# Dropdown(description='Items:', index=8, options=('artworkColors.json', 'artworkEmotions.json', 'Clean_users.cs…
# Dropdown(description='Users:', index=14, options=('artworkColors.json', 'artworkEmotions.json', 'Clean_users.c…

# %%
users, artworks = cargarDatos(data_path, usersDropdown, itemsDropdown)
atr_dropdowns, colorDropdown = elegirSimilitudItems(data_path, files, artworks)
for key, value in atr_dropdowns.items():
  display(value)
display(colorDropdown)
# Out:
# Dropdown(description='ID', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'SimilarityColors'), value…
# Dropdown(description='Category', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'SimilarityColors'),…
# Dropdown(description='Artist', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'SimilarityColors'), v…
# Dropdown(description='Title', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'SimilarityColors'), va…
# Dropdown(description='Year', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'SimilarityColors'), val…
# Dropdown(description='Image URL', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'SimilarityColors')…
# Dropdown(description='Painting Info URL', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'Similarity…
# Dropdown(description='Artist Info URL', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'SimilarityCo…
# Dropdown(description='Location', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'SimilarityColors'),…
# Dropdown(description='wd:paintingID', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'SimilarityColo…
# Dropdown(description='wd:paintingURL', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'SimilarityCol…
# Dropdown(description='wd:artistID', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'SimilarityColors…
# Dropdown(description='wd:artistURL', options=(None, 'SimilarityArtist', 'SimilarityCategory', 'SimilarityColor…
# Dropdown(description='Colors', options=('artworkColors.json', 'artworkEmotions.json', 'Clean_users.csv', 'coun…

# %%
# atributes_artworks = [i for i in [value.value for key, value in atr_dropdowns.items()] if i]
atributes_artworks = [key for key,value in atr_dropdowns.items() if value is not None]

float_texts, colorFloatText = elegirPesosItems(atr_dropdowns, colorDropdown)
for key, value in float_texts.items():
  display(value)

if colorDropdown.value is not None:
  display(colorFloatText)
# Out:
# FloatText(value=0.3, description='Category', step=0.1)
# FloatText(value=0.3, description='Artist', step=0.1)
# FloatText(value=0.3, description='Colors', step=0.1)

# %%
artworks_sim = calcularSimilitudItems(data_path, artworks, atr_dropdowns, float_texts)

# %%
artworks_sim
# Out:
#                           57726f48edc2cb3880ba012f  57726e34edc2cb3880b62340  \
# 57726f48edc2cb3880ba012f                       1.0                       0.0
# 57726e34edc2cb3880b62340                       0.0                       1.0
# 57726f56edc2cb3880ba7233                       1.0                       0.0
# 57727c95edc2cb3880e4d1d4                       0.
#
#                           5772700eedc2cb3880bc82ce
# 57726f48edc2cb3880ba012f                       0.0
# 57726e34edc2cb3880b62340                       0.0
# 57726f56edc2cb3880ba7233                       0.0
# 57727c95edc2cb3880e4d1d4                       0.0
# 57727016edc2cb3880bceb88                       1.0
# 57726f78edc2cb3880baa755                       0.0
# 57726f4cedc2cb3880ba07ed                       0.0
# 57726f76edc2cb3880baa425                       0.0
# 57726f4fedc2cb3880ba0b6d                       0.0
# 5772700eedc2cb3880bc836e                       1.0
# 57727015edc2cb3880bceb08                       1.0
# 57726f77edc2cb3880baa4c5                       0.0
# 57726e45edc2cb3880b69781                       0.0
# 57727c88edc2cb3880e4be65                       0.0
# 57727cbaedc2cb3880e561f7                       0.0
# 57727d14edc2cb3880e6926e                       0.0
# 57726fffedc2cb3880bc69d6                       0.0
# 57727d5cedc2cb3880e751a0                       0.0
# 57727c2eedc2cb3880e392f5                       0.0
# 57726f59edc2cb3880ba76b3                       0.0
# 577271fdedc2cb3880c384cc                       0.0
# 57727015edc2cb3880bceb28                       1.0
# 57727071edc2cb3880be3213                       0.0
# 57726e37edc2cb3880b628ee                       0.5
# 57726f49edc2cb3880ba034f                       0.0
# 577278d5edc2cb3880d94196                       0.0
# 5772752eedc2cb3880cd9f38                       0.5
# 57727c2eedc2cb3880e39405                       0.0
# 577278cdedc2cb3880d9370c                       0.0
# 5772700eedc2cb3880bc82ce                       1.0
#
# [30 rows x 30 columns]

# %%
atr_dropdowns = elegirSimilitudUsers(data_path, files, users)
for key, value in atr_dropdowns.items():
  display(value)
# Out:
# Dropdown(description='userId', options=(None, 'SimilarityAge', 'SimilarityGender', 'SimilarityCountry', 'Simil…
# Dropdown(description='age', options=(None, 'SimilarityAge', 'SimilarityGender', 'SimilarityCountry', 'Similari…
# Dropdown(description='gender', options=(None, 'SimilarityAge', 'SimilarityGender', 'SimilarityCountry', 'Simil…
# Dropdown(description='country', options=(None, 'SimilarityAge', 'SimilarityGender', 'SimilarityCountry', 'Simi…
# Dropdown(description='positive', options=(None, 'SimilarityAge', 'SimilarityGender', 'SimilarityCountry', 'Sim…
# Dropdown(description='negative', options=(None, 'SimilarityAge', 'SimilarityGender', 'SimilarityCountry', 'Sim…
# Dropdown(description='mixed', options=(None, 'SimilarityAge', 'SimilarityGender', 'SimilarityCountry', 'Simila…

# %%
# atributes_users = [i for i in [value.value for key, value in atr_dropdowns.items()] if i]
atributes_users = [key for key,value in atr_dropdowns.items() if value is not None]
float_texts, demographicFloatText, polarityFloatText = elegirPesosUsers(atr_dropdowns)
display(demographicFloatText)
display(polarityFloatText)
for key, value in float_texts.items():
  display(value)
# Out:
# FloatText(value=0.5, description='Demographic', step=0.1)
# FloatText(value=0.5, description='Polarity', step=0.1)
# FloatText(value=0.3, description='age', step=0.1)
# FloatText(value=0.3, description='gender', step=0.1)
# FloatText(value=0.3, description='positive', step=0.1)
# FloatText(value=0.3, description='negative', step=0.1)
# FloatText(value=0.3, description='mixed', step=0.1)

# %%
users_sim = calcularSimilitudUsers(data_path, users, artworks_sim, atr_dropdowns, float_texts, demographicFloatText, polarityFloatText)

# %%
# %%capture output
users_clustered = calcularClusters(users, users_sim)

# %%
AU = AverageUser(users_clustered, artworks, atributes_users, atributes_artworks)

# %%
explicators = AU.computeAverageUser()
explicators
# Out:
#     userId    age  gender country  \
# 0  expl307  45-54    male   Spain
# 1  expl308  35-44  female   Spain
# 2  expl309  35-44  female   Spain
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q20175244
# 			wd:paintingURL: http://www.wikidata.org/entity/Q20175244
# 			wd:artistID: Q333380
# 			wd:artistURL: http://www.wikidata.org/entity/Q333380
# 			Title:St. Rufina of Seville
# 			ID: 57727015edc2cb3880bceb08
# 			Category: Baroque
# 			Artist: Francisco de Zurbaran
# 			Title: St. Rufina of Seville
# 			Year: 1635-1640
# 			Image URL: https://uploads6.wikiart.org/images/francisco-zurbaran/st-rufina-of-seville-1640.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-de-zurbaran/st-rufina-of-seville-1640
# 			Artist Info URL: https://www.wikiart.org/en/francisco-de-zurbaran
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q77992354
# 			wd:paintingURL: http://www.wikidata.org/entity/Q77992354
# 			wd:artistID: Q209615
# 			wd:artistURL: http://www.wikidata.org/entity/Q209615
# ------------------------
# Cluster:  1
# 	Individuos:  53
# 	age :
# 		 35-44 ( 30.18867924528302 %)
# 	gender :
# 		 female ( 58.490566037735846 %)
# 	country :
# 		 Spain ( 43.39622641509434 %)
# 	--Top 3  mixed--
# 			Title:The Surgeon
# 			ID: 57727cbaedc2cb3880e561f7
# 			Category: Northern Renaissance
# 			Artist: Jan van Hemessen
# 			Title: The Surgeon
# 			Year: XVI cent.
# 			Image URL: https://uploads8.wikiart.org/images/jan-van-hemessen/the-surgeon.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/jan-van-hemessen/the-surgeon
# 			Artist Info URL: https://www.wikiart.org/en/jan-van-hemessen
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q5853603
# 			wd:paintingURL: http://www.wikidata.org/entity/Q5853603
# 			wd:artistID: Q427870
# 			wd:artistURL: http://www.wikidata.org/entity/Q427870
# 			Title:The Straw Manikin
# 			ID: 57726f59edc2cb3880ba76b3
# 			Category: Romanticism
# 			Artist: Francisco Goya
# 			Title: The Straw Manikin
# 			Year: 1791-1792
# 			Image URL: https://uploads2.wikiart.org/00237/images/francisco-goya/the-straw-manikin.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-goya/the-straw-manikin-1792
# 			Artist Info URL: https://www.wikiart.org/en/francisco-goya
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q952796
# 			wd:paintingURL: http://www.wikidata.org/entity/Q952796
# 			wd:artistID: Q5432
# 			wd:artistURL: http://www.wikidata.org/entity/Q5432
# 			Title:The Triumph of Death
# 			ID: 57726e45edc2cb3880b69781
# 			Category: Northern Renaissance
# 			Artist: Pieter Bruegel the Elder
# 			Title: The Triumph of Death
# 			Year: 1562-1563
# 			Image URL: https://uploads7.wikiart.org/images/pieter-bruegel-the-elder/the-triumph-of-death.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/pieter-bruegel-the-elder/the-triumph-of-death-1562-1
# 			Artist Info URL: https://www.wikiart.org/en/pieter-bruegel-the-elder
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q644856
# 			wd:paintingURL: http://www.wikidata.org/entity/Q644856
# 			wd:artistID: Q43270
# 			wd:artistURL: http://www.wikidata.org/entity/Q43270
# 	--Top 3  negative--
# 			Title:The Surgeon
# 			ID: 57727cbaedc2cb3880e561f7
# 			Category: Northern Renaissance
# 			Artist: Jan van Hemessen
# 			Title: The Surgeon
# 			Year: XVI cent.
# 			Image URL: https://uploads8.wikiart.org/images/jan-van-hemessen/the-surgeon.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/jan-van-hemessen/the-surgeon
# 			Artist Info URL: https://www.wikiart.org/en/jan-van-hemessen
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q5853603
# 			wd:paintingURL: http://www.wikidata.org/entity/Q5853603
# 			wd:artistID: Q427870
# 			wd:artistURL: http://www.wikidata.org/entity/Q427870
# 			Title:The Straw Manikin
# 			ID: 57726f59edc2cb3880ba76b3
# 			Category: Romanticism
# 			Artist: Francisco Goya
# 			Title: The Straw Manikin
# 			Year: 1791-1792
# 			Image URL: https://uploads2.wikiart.org/00237/images/francisco-goya/the-straw-manikin.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-goya/the-straw-manikin-1792
# 			Artist Info URL: https://www.wikiart.org/en/francisco-goya
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q952796
# 			wd:paintingURL: http://www.wikidata.org/entity/Q952796
# 			wd:artistID: Q5432
# 			wd:artistURL: http://www.wikidata.org/entity/Q5432
# 			Title:Apparition of the Apostle Peter to Saint Peter Nolasco
# 			ID: 5772700eedc2cb3880bc82ce
# 			Category: Baroque
# 			Artist: Francisco de Zurbaran
# 			Title: Apparition of the Apostle Peter to Saint Peter Nolasco
# 			Year: 1629
# 			Image URL: https://uploads1.wikiart.org/images/francisco-zurbaran/appearance-of-st-peter-to-st-peter-nolasco-1629.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-de-zurbaran/appearance-of-st-peter-to-st-peter-nolasco-1629
# 			Artist Info URL: https://www.wikiart.org/en/francisco-de-zurbaran
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q8202299
# 			wd:paintingURL: http://www.wikidata.org/entity/Q8202299
# 			wd:artistID: Q209615
# 			wd:artistURL: http://www.wikidata.org/entity/Q209615
# 	--Top 3  positive--
# 			Title:The Straw Manikin
# 			ID: 57726f59edc2cb3880ba76b3
# 			Category: Romanticism
# 			Artist: Francisco Goya
# 			Title: The Straw Manikin
# 			Year: 1791-1792
# 			Image URL: https://uploads2.wikiart.org/00237/images/francisco-goya/the-straw-manikin.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-goya/the-straw-manikin-1792
# 			Artist Info URL: https://www.wikiart.org/en/francisco-goya
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q952796
# 			wd:paintingURL: http://www.wikidata.org/entity/Q952796
# 			wd:artistID: Q5432
# 			wd:artistURL: http://www.wikidata.org/entity/Q5432
# 			Title:The Surgeon
# 			ID: 57727cbaedc2cb3880e561f7
# 			Category: Northern Renaissance
# 			Artist: Jan van Hemessen
# 			Title: The Surgeon
# 			Year: XVI cent.
# 			Image URL: https://uploads8.wikiart.org/images/jan-van-hemessen/the-surgeon.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/jan-van-hemessen/the-surgeon
# 			Artist Info URL: https://www.wikiart.org/en/jan-van-hemessen
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q5853603
# 			wd:paintingURL: http://www.wikidata.org/entity/Q5853603
# 			wd:artistID: Q427870
# 			wd:artistURL: http://www.wikidata.org/entity/Q427870
# 			Title:Adoration of the Magi Triptych
# 			ID: 577271fdedc2cb3880c384cc
# 			Category: Northern Renaissance
# 			Artist: Hans Memling
# 			Title: Adoration of the Magi Triptych
# 			Year: 1470
# 			Image URL: https://uploads2.wikiart.org/images/hans-memling/adoration-of-the-magi-whole-triptych.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/hans-memling/adoration-of-the-magi-whole-triptych
# 			Artist Info URL: https://www.wikiart.org/en/hans-memling
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q14858463
# 			wd:paintingURL: http://www.wikidata.org/entity/Q14858463
# 			wd:artistID: Q106851
# 			wd:artistURL: http://www.wikidata.org/entity/Q106851
# ------------------------
# Cluster:  3
# 	Individuos:  16
# 	age :
# 		 35-44 ( 37.5 %)
# 	gender :
# 		 female ( 75.0 %)
# 	country :
# 		 Spain ( 31.25 %)
# 	--Top 3  mixed--
# 			Title:The Surgeon
# 			ID: 57727cbaedc2cb3880e561f7
# 			Category: Northern Renaissance
# 			Artist: Jan van Hemessen
# 			Title: The Surgeon
# 			Year: XVI cent.
# 			Image URL: https://uploads8.wikiart.org/images/jan-van-hemessen/the-surgeon.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/jan-van-hemessen/the-surgeon
# 			Artist Info URL: https://www.wikiart.org/en/jan-van-hemessen
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q5853603
# 			wd:paintingURL: http://www.wikidata.org/entity/Q5853603
# 			wd:artistID: Q427870
# 			wd:artistURL: http://www.wikidata.org/entity/Q427870
# 			Title:St. Rufina of Seville
# 			ID: 57727015edc2cb3880bceb08
# 			Category: Baroque
# 			Artist: Francisco de Zurbaran
# 			Title: St. Rufina of Seville
# 			Year: 1635-1640
# 			Image URL: https://uploads6.wikiart.org/images/francisco-zurbaran/st-rufina-of-seville-1640.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-de-zurbaran/st-rufina-of-seville-1640
# 			Artist Info URL: https://www.wikiart.org/en/francisco-de-zurbaran
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q77992354
# 			wd:paintingURL: http://www.wikidata.org/entity/Q77992354
# 			wd:artistID: Q209615
# 			wd:artistURL: http://www.wikidata.org/entity/Q209615
# 			Title:The Werl Triptych
# 			ID: 577278cdedc2cb3880d9370c
# 			Category: Northern Renaissance
# 			Artist: Robert Campin
# 			Title: The Werl Triptych
# 			Year: 1438
# 			Image URL: https://uploads5.wikiart.org/images/robert-campin/werl-altarpiece-1438.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/robert-campin/werl-altarpiece-1438
# 			Artist Info URL: https://www.wikiart.org/en/robert-campin
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q3136106
# 			wd:paintingURL: http://www.wikidata.org/entity/Q3136106
# 			wd:artistID: Q80442
# 			wd:artistURL: http://www.wikidata.org/entity/Q80442
# 	--Top 3  negative--
# 			Title:The Surgeon
# 			ID: 57727cbaedc2cb3880e561f7
# 			Category: Northern Renaissance
# 			Artist: Jan van Hemessen
# 			Title: The Surgeon
# 			Year: XVI cent.
# 			Image URL: https://uploads8.wikiart.org/images/jan-van-hemessen/the-surgeon.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/jan-van-hemessen/the-surgeon
# 			Artist Info URL: https://www.wikiart.org/en/jan-van-hemessen
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q5853603
# 			wd:paintingURL: http://www.wikidata.org/entity/Q5853603
# 			wd:artistID: Q427870
# 			wd:artistURL: http://www.wikidata.org/entity/Q427870
# 			Title:The Three Ages of Man and Death
# 			ID: 577278d5edc2cb3880d94196
# 			Category: Northern Renaissance
# 			Artist: Hans Baldung
# 			Title: The Three Ages of Man and Death
# 			Year: 1539
# 			Image URL: https://uploads5.wikiart.org/images/hans-baldung/three-ages-of-man-and-three-graces-1539.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/hans-baldung/three-ages-of-man-and-three-graces-1539
# 			Artist Info URL: https://www.wikiart.org/en/hans-baldung
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q4462828
# 			wd:paintingURL: http://www.wikidata.org/entity/Q4462828
# 			wd:artistID: Q164696
# 			wd:artistURL: http://www.wikidata.org/entity/Q164696
# 			Title:The Extraction of the Stone Madness
# 			ID: 57726f76edc2cb3880baa425
# 			Category: Northern Renaissance
# 			Artist: Hieronymus Bosch
# 			Title: The Extraction of the Stone Madness
# 			Year: 1494-1516
# 			Image URL: https://uploads5.wikiart.org/images/hieronymus-bosch/the-cure-of-folly.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/hieronymus-bosch/the-stone-operation-the-extraction-of-the-stone-madness-the-cure-of-folly-1
# 			Artist Info URL: https://www.wikiart.org/en/hieronymus-bosch
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q2270768
# 			wd:paintingURL: http://www.wikidata.org/entity/Q2270768
# 			wd:artistID: Q130531
# 			wd:artistURL: http://www.wikidata.org/entity/Q130531
# 	--Top 3  positive--
# 			Title:The Straw Manikin
# 			ID: 57726f59edc2cb3880ba76b3
# 			Category: Romanticism
# 			Artist: Francisco Goya
# 			Title: The Straw Manikin
# 			Year: 1791-1792
# 			Image URL: https://uploads2.wikiart.org/00237/images/francisco-goya/the-straw-manikin.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-goya/the-straw-manikin-1792
# 			Artist Info URL: https://www.wikiart.org/en/francisco-goya
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q952796
# 			wd:paintingURL: http://www.wikidata.org/entity/Q952796
# 			wd:artistID: Q5432
# 			wd:artistURL: http://www.wikidata.org/entity/Q5432
# 			Title:Rest on the Flight into Egypt
# 			ID: 57727c95edc2cb3880e4d1d4
# 			Category: Northern Renaissance
# 			Artist: Gerard David
# 			Title: Rest on the Flight into Egypt
# 			Year: 1510-1515
# 			Image URL: https://uploads8.wikiart.org/images/gerard-david/a-rest-during-the-flight-to-egypt.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/gerard-david/a-rest-during-the-flight-to-egypt
# 			Artist Info URL: https://www.wikiart.org/en/gerard-david
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q20175244
# 			wd:paintingURL: http://www.wikidata.org/entity/Q20175244
# 			wd:artistID: Q333380
# 			wd:artistURL: http://www.wikidata.org/entity/Q333380
# 			Title:St. Rufina of Seville
# 			ID: 57727015edc2cb3880bceb08
# 			Category: Baroque
# 			Artist: Francisco de Zurbaran
# 			Title: St. Rufina of Seville
# 			Year: 1635-1640
# 			Image URL: https://uploads6.wikiart.org/images/francisco-zurbaran/st-rufina-of-seville-1640.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-de-zurbaran/st-rufina-of-seville-1640
# 			Artist Info URL: https://www.wikiart.org/en/francisco-de-zurbaran
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q77992354
# 			wd:paintingURL: http://www.wikidata.org/entity/Q77992354
# 			wd:artistID: Q209615
# 			wd:artistURL: http://www.wikidata.org/entity/Q209615
# ------------------------
# Cluster:  4
# 	Individuos:  22
# 	age :
# 		 45-54 ( 31.818181818181817 %)
# 	gender :
# 		 female ( 100.0 %)
# 	country :
# 		 Spain ( 36.36363636363637 %)
# 	--Top 3  mixed--
# 			Title:The Surgeon
# 			ID: 57727cbaedc2cb3880e561f7
# 			Category: Northern Renaissance
# 			Artist: Jan van Hemessen
# 			Title: The Surgeon
# 			Year: XVI cent.
# 			Image URL: https://uploads8.wikiart.org/images/jan-van-hemessen/the-surgeon.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/jan-van-hemessen/the-surgeon
# 			Artist Info URL: https://www.wikiart.org/en/jan-van-hemessen
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q5853603
# 			wd:paintingURL: http://www.wikidata.org/entity/Q5853603
# 			wd:artistID: Q427870
# 			wd:artistURL: http://www.wikidata.org/entity/Q427870
# 			Title:The Third of May 1808
# 			ID: 57726f49edc2cb3880ba034f
# 			Category: Romanticism
# 			Artist: Francisco Goya
# 			Title: The Third of May 1808
# 			Year: 1814
# 			Image URL: https://uploads4.wikiart.org/images/francisco-goya/execution-of-the-defenders-of-madrid-3rd-may-1808-1814.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-goya/the-third-of-may-1808-execution-of-the-defenders-of-madrid-1814-1
# 			Artist Info URL: https://www.wikiart.org/en/francisco-goya
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q1091086
# 			wd:paintingURL: http://www.wikidata.org/entity/Q1091086
# 			wd:artistID: Q5432
# 			wd:artistURL: http://www.wikidata.org/entity/Q5432
# 			Title:The Three Ages of Man and Death
# 			ID: 577278d5edc2cb3880d94196
# 			Category: Northern Renaissance
# 			Artist: Hans Baldung
# 			Title: The Three Ages of Man and Death
# 			Year: 1539
# 			Image URL: https://uploads5.wikiart.org/images/hans-baldung/three-ages-of-man-and-three-graces-1539.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/hans-baldung/three-ages-of-man-and-three-graces-1539
# 			Artist Info URL: https://www.wikiart.org/en/hans-baldung
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q4462828
# 			wd:paintingURL: http://www.wikidata.org/entity/Q4462828
# 			wd:artistID: Q164696
# 			wd:artistURL: http://www.wikidata.org/entity/Q164696
# 	--Top 3  negative--
# 			Title:The Surgeon
# 			ID: 57727cbaedc2cb3880e561f7
# 			Category: Northern Renaissance
# 			Artist: Jan van Hemessen
# 			Title: The Surgeon
# 			Year: XVI cent.
# 			Image URL: https://uploads8.wikiart.org/images/jan-van-hemessen/the-surgeon.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/jan-van-hemessen/the-surgeon
# 			Artist Info URL: https://www.wikiart.org/en/jan-van-hemessen
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q5853603
# 			wd:paintingURL: http://www.wikidata.org/entity/Q5853603
# 			wd:artistID: Q427870
# 			wd:artistURL: http://www.wikidata.org/entity/Q427870
# 			Title:The Triumph of Death
# 			ID: 57726e45edc2cb3880b69781
# 			Category: Northern Renaissance
# 			Artist: Pieter Bruegel the Elder
# 			Title: The Triumph of Death
# 			Year: 1562-1563
# 			Image URL: https://uploads7.wikiart.org/images/pieter-bruegel-the-elder/the-triumph-of-death.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/pieter-bruegel-the-elder/the-triumph-of-death-1562-1
# 			Artist Info URL: https://www.wikiart.org/en/pieter-bruegel-the-elder
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q644856
# 			wd:paintingURL: http://www.wikidata.org/entity/Q644856
# 			wd:artistID: Q43270
# 			wd:artistURL: http://www.wikidata.org/entity/Q43270
# 			Title:The Third of May 1808
# 			ID: 57726f49edc2cb3880ba034f
# 			Category: Romanticism
# 			Artist: Francisco Goya
# 			Title: The Third of May 1808
# 			Year: 1814
# 			Image URL: https://uploads4.wikiart.org/images/francisco-goya/execution-of-the-defenders-of-madrid-3rd-may-1808-1814.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-goya/the-third-of-may-1808-execution-of-the-defenders-of-madrid-1814-1
# 			Artist Info URL: https://www.wikiart.org/en/francisco-goya
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q1091086
# 			wd:paintingURL: http://www.wikidata.org/entity/Q1091086
# 			wd:artistID: Q5432
# 			wd:artistURL: http://www.wikidata.org/entity/Q5432
# 	--Top 3  positive--
# 			Title:Rest on the Flight into Egypt
# 			ID: 57727c95edc2cb3880e4d1d4
# 			Category: Northern Renaissance
# 			Artist: Gerard David
# 			Title: Rest on the Flight into Egypt
# 			Year: 1510-1515
# 			Image URL: https://uploads8.wikiart.org/images/gerard-david/a-rest-during-the-flight-to-egypt.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/gerard-david/a-rest-during-the-flight-to-egypt
# 			Artist Info URL: https://www.wikiart.org/en/gerard-david
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q20175244
# 			wd:paintingURL: http://www.wikidata.org/entity/Q20175244
# 			wd:artistID: Q333380
# 			wd:artistURL: http://www.wikidata.org/entity/Q333380
# 			Title:The Straw Manikin
# 			ID: 57726f59edc2cb3880ba76b3
# 			Category: Romanticism
# 			Artist: Francisco Goya
# 			Title: The Straw Manikin
# 			Year: 1791-1792
# 			Image URL: https://uploads2.wikiart.org/00237/images/francisco-goya/the-straw-manikin.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-goya/the-straw-manikin-1792
# 			Artist Info URL: https://www.wikiart.org/en/francisco-goya
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q952796
# 			wd:paintingURL: http://www.wikidata.org/entity/Q952796
# 			wd:artistID: Q5432
# 			wd:artistURL: http://www.wikidata.org/entity/Q5432
# 			Title:St. Rufina of Seville
# 			ID: 57727015edc2cb3880bceb08
# 			Category: Baroque
# 			Artist: Francisco de Zurbaran
# 			Title: St. Rufina of Seville
# 			Year: 1635-1640
# 			Image URL: https://uploads6.wikiart.org/images/francisco-zurbaran/st-rufina-of-seville-1640.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-de-zurbaran/st-rufina-of-seville-1640
# 			Artist Info URL: https://www.wikiart.org/en/francisco-de-zurbaran
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q77992354
# 			wd:paintingURL: http://www.wikidata.org/entity/Q77992354
# 			wd:artistID: Q209615
# 			wd:artistURL: http://www.wikidata.org/entity/Q209615
# ------------------------
# Cluster:  5
# 	Individuos:  9
# 	age :
# 		 55-64 ( 55.55555555555556 %)
# 	gender :
# 		 female ( 88.88888888888889 %)
# 	country :
# 		 Spain ( 33.33333333333333 %)
# 	--Top 3  mixed--
# 			Title:St. Rufina of Seville
# 			ID: 57727015edc2cb3880bceb08
# 			Category: Baroque
# 			Artist: Francisco de Zurbaran
# 			Title: St. Rufina of Seville
# 			Year: 1635-1640
# 			Image URL: https://uploads6.wikiart.org/images/francisco-zurbaran/st-rufina-of-seville-1640.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-de-zurbaran/st-rufina-of-seville-1640
# 			Artist Info URL: https://www.wikiart.org/en/francisco-de-zurbaran
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q77992354
# 			wd:paintingURL: http://www.wikidata.org/entity/Q77992354
# 			wd:artistID: Q209615
# 			wd:artistURL: http://www.wikidata.org/entity/Q209615
# 	--Top 3  negative--
# 			Title:Summer, or The Harvest
# 			ID: 57726f56edc2cb3880ba7233
# 			Category: Romanticism
# 			Artist: Francisco Goya
# 			Title: Summer, or The Harvest
# 			Year: 1786
# 			Image URL: https://uploads3.wikiart.org/images/francisco-goya/summer-or-the-harvest-1786.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-goya/summer-or-the-harvest-1786
# 			Artist Info URL: https://www.wikiart.org/en/francisco-goya
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q5849818
# 			wd:paintingURL: http://www.wikidata.org/entity/Q5849818
# 			wd:artistID: Q5432
# 			wd:artistURL: http://www.wikidata.org/entity/Q5432
# 			Title:The Surgeon
# 			ID: 57727cbaedc2cb3880e561f7
# 			Category: Northern Renaissance
# 			Artist: Jan van Hemessen
# 			Title: The Surgeon
# 			Year: XVI cent.
# 			Image URL: https://uploads8.wikiart.org/images/jan-van-hemessen/the-surgeon.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/jan-van-hemessen/the-surgeon
# 			Artist Info URL: https://www.wikiart.org/en/jan-van-hemessen
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q5853603
# 			wd:paintingURL: http://www.wikidata.org/entity/Q5853603
# 			wd:artistID: Q427870
# 			wd:artistURL: http://www.wikidata.org/entity/Q427870
# 	--Top 3  positive--
# 			Title:The Straw Manikin
# 			ID: 57726f59edc2cb3880ba76b3
# 			Category: Romanticism
# 			Artist: Francisco Goya
# 			Title: The Straw Manikin
# 			Year: 1791-1792
# 			Image URL: https://uploads2.wikiart.org/00237/images/francisco-goya/the-straw-manikin.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/francisco-goya/the-straw-manikin-1792
# 			Artist Info URL: https://www.wikiart.org/en/francisco-goya
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q952796
# 			wd:paintingURL: http://www.wikidata.org/entity/Q952796
# 			wd:artistID: Q5432
# 			wd:artistURL: http://www.wikidata.org/entity/Q5432
# 			Title:The Pearl of Brabant
# 			ID: 57727c2eedc2cb3880e39405
# 			Category: Northern Renaissance
# 			Artist: Dirk Bouts
# 			Title: The Pearl of Brabant
# 			Year: 1468
# 			Image URL: https://uploads2.wikiart.org/images/dirk-bouts/the-right-wing-of-the-pearl-of-brabant-saint-christopher.jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/dirk-bouts/the-right-wing-of-the-pearl-of-brabant-saint-christopher
# 			Artist Info URL: https://www.wikiart.org/en/dirk-bouts
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q27518363
# 			wd:paintingURL: http://www.wikidata.org/entity/Q27518363
# 			wd:artistID: Q313561
# 			wd:artistURL: http://www.wikidata.org/entity/Q313561
# 			Title:Noli Me Tangere
# 			ID: 57726e34edc2cb3880b62340
# 			Category: High Renaissance
# 			Artist: Correggio
# 			Title: Noli Me Tangere
# 			Year: 1534
# 			Image URL: https://uploads1.wikiart.org/images/correggio/noli-me-tangere-1(2).jpg!Large.jpg
# 			Painting Info URL: https://www.wikiart.org/en/correggio/noli-me-tangere-1
# 			Artist Info URL: https://www.wikiart.org/en/correggio
# 			Location: Museo del Prado, Madrid, Spain
# 			wd:paintingID: Q124362
# 			wd:paintingURL: http://www.wikidata.org/entity/Q124362
# 			wd:artistID: Q8457
# 			wd:artistURL: http://www.wikidata.org/entity/Q8457
