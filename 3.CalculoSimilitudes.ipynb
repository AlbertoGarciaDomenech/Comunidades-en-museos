# %% [markdown]
# # Calculo de las matrices de similitud
# Calcular las similitudes entre obras y entre usuarios y generar matrices de similitud para usarlas posteriormente
#
# ---

# %%
import numpy as np
import pandas as pd
import src.SimilarityUsers as su
import src.SimilarityArtworks as sa

# %% [markdown]
# ## 1. Similitud Cuadros

# %%
artworks_csv = pd.read_csv(sa.ARTWORKS_CSV)
artworks_matrix = np.zeros((len(artworks_csv),len(artworks_csv)))

i = 0
for a in artworks_csv['ID']:
    j = 0
    for b in artworks_csv['ID']:
        artworks_matrix[i][j] = sa.SimilarityArtworks().computeSimilarity(a, b)
        j +=1
    i+=1

# %%
artworks_sim = pd.DataFrame(artworks_matrix, index = [i for i in artworks_csv['ID']], columns = [i for i in artworks_csv['ID']])
artworks_sim.to_csv('data/Prado_artworks_similarity.csv')

# %% [markdown]
# ## 2. Similitud usuarios

# %%
artworks_sim = pd.read_csv('data/Prado_artworks_similarity.csv', index_col = 0)

users_csv = pd.read_csv(su.USERS_EMOTIONS_SCALED_CSV)
# Tratar las listas de emociones para que no se lean como strings
users_csv['positive'] = users_csv['positive'].apply(eval)
users_csv['negative'] = users_csv['negative'].apply(eval)
users_csv['mixed'] = users_csv['mixed'].apply(eval)
users_matrix = []

SimUsers = su.SimilarityUsers(age_index = np.count_nonzero(users_csv['age'].unique()), artworks_sim = artworks_sim)

# %%
for i in range(0, len(users_csv)):
  sim_list = []
  for j in range(0, len(users_csv)):
    sim = SimUsers.computeSimilarity(users_csv.loc(0)[i]['userId'], users_csv.loc(0)[j]['userId'])
    if sim >= 0:
      sim_list.append(sim)
    else:
      sim_list.append(0)
      
  users_matrix.append(sim_list)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10300/2822309770.py in <module>
#       2   sim_list = []
#       3   for j in range(0, len(users_csv)):
# ----> 4     sim = SimUsers.computeSimilarity(users_csv.loc(0)[i]['userId'], users_csv.loc(0)[j]['userId'])
#       5     if sim >= 0:
#       6       sim_list.append(sim)
#
# ~\Desktop\Comunidades-en-museos\src\SimilarityUsers.py in computeSimilarity(self, A, B)
#     145     def computeSimilarity(self, A, B):
#     146         """Overrides SimilarityFunctionInterface.computeSimilarity()"""
# --> 147         demog_sim = SimilarityDemographic(self.age_index).computeSimilarity(A, B)
#     148         artw_sim = SimilarityPolarity(self.artworks_sim).computeSimilarity(A, B)
#     149         return (self.demog_weight * demog_sim) + (self.artw_weight * artw_sim)
#
# ~\Desktop\Comunidades-en-museos\src\SimilarityUsers.py in computeSimilarity(self, A, B)
#      55     def computeSimilarity(self, A, B):
#      56         """Overrides SimilarityFuntionInterface.computeSimilarity()"""
# ---> 57         country_sim = SimilarityCountry().computeSimilarity(A, B)
#      58         age_sim = SimilarityAge(self.age_index).computeSimilarity(A, B)
#      59         gender_sim = SimilarityGender().computeSimilarity(A, B)
#
# ~\Desktop\Comunidades-en-museos\src\SimilarityUsers.py in __init__(self, data_csv)
#      35     """Compute similarity between users (by age)"""
#      36     def __init__(self, data_csv=USERS_EMOTIONS_SCALED_CSV):
# ---> 37         self.data = pd.read_csv(data_csv)
#      38
#      39     def computeSimilarity(self, A, B):
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1067             new_rows = len(index)
#    1068
# -> 1069         df = DataFrame(col_dict, columns=columns, index=index)
#    1070
#    1071         self._currow += new_rows
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      93     axes = [columns, index]
#      94
# ---> 95     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      96
#      97
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1699     arrays = [x if not isinstance(x, ABCPandasArray) else x.to_numpy() for x in arrays]
#    1700     try:
# -> 1701         blocks = _form_blocks(arrays, names, axes)
#    1702         mgr = BlockManager(blocks, axes)
#    1703         mgr._consolidate_inplace()
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py in _form_blocks(arrays, names, axes)
#    1757     blocks: List[Block] = []
#    1758     if len(items_dict["FloatBlock"]):
# -> 1759         float_blocks = _multi_blockify(items_dict["FloatBlock"])
#    1760         blocks.extend(float_blocks)
#    1761
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py in _multi_blockify(tuples, dtype)
#    1850     for dtype, tup_block in grouper:
#    1851
# -> 1852         values, placement = _stack_arrays(list(tup_block), dtype)
#    1853
#    1854         block = make_block(values, placement=placement, ndim=2)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py in _stack_arrays(tuples, dtype)
#    1880     stacked = np.empty(shape, dtype=dtype)
#    1881     for i, arr in enumerate(arrays):
# -> 1882         stacked[i] = _asarray_compat(arr)
#    1883
#    1884     return stacked, placement
#
# KeyboardInterrupt:

# %%
users_sim = pd.DataFrame(users_matrix, index = [i for i in users_csv['userId']], columns = [i for i in users_csv['userId']])
users_sim.to_csv('data/Prado_users_similarity.csv')

# %% [markdown]
# ### Anexo: Similitud de individuos explicadores
# Similitud con los individuos explicadores de cada cluster, generados externamenteprado_users = pd.read_csv('data/Prado_users_emotions.csv')prado_users = pd.read_csv('data/Prado_users_emotions.csv')

# %%
artworks_sim = pd.read_csv('data/Prado_artworks_similarity.csv', index_col = 0)

users_csv = pd.read_csv('data/Prado_users_individuo_explicador.csv')
# Tratar las listas de emociones para que no se lean como strings
users_csv['positive'] = users_csv['positive'].apply(eval)
users_csv['negative'] = users_csv['negative'].apply(eval)
users_csv['mixed'] = users_csv['mixed'].apply(eval)
users_matrix = []

SimUsers = su.SimilarityUsers(age_index = np.count_nonzero(users_csv['age'].unique()), artworks_sim = artworks_sim)

# %%
users_csv
# Out:
#     userId       age    gender   country  \
# 0        1  4.107464  2.021723  1.787405
# 1        2  2.347123  0.000000  1.787405
# 2        3  1.760342  0.000000  1.787405
# 3        4  1.760342  0.000000  1.787405
# 4        5  2.933903  2.021723  1.787405
# ..     ...       ...       ...       ...
# 168    300  2.347123  0.000000  1.787405
# 169    301  3.520684  2.021723  1.787405
# 170    306  4.107464  2.021723  1.787405
# 171  expl0  2.933903  2.021723  1.787405
# 172  expl1  2.933903  0.000000  1.787405
#
#                                               positive  \
# 0    [57726f4cedc2cb3880ba07ed, 57726f4cedc2cb3880b...
# 1                                                   []
# 2    [577278d5edc2cb3880d94196, 5772752eedc2cb3880c...
# 3    [577278d5edc2cb3880d94196, 57726f59edc2cb3880b...
# 4    [57726e34edc2cb3880b62340, 57726e34edc2cb3880b...
# ..                                                 ...
# 168  [57727cbaedc2cb3880e561f7, 57727cbaedc2cb3880e...
# 169                                                 []
# 170  [57726f59edc2cb3880ba76b3, 57726f59edc2cb3880b...
# 171  [57726f4cedc2cb3880ba07ed, 57726f4cedc2cb3880b...
# 172  [577278d5edc2cb3880d94196, 5772752eedc2cb3880c...
#
#                                               negative  \
# 0    [577278d5edc2cb3880d94196, 57727015edc2cb3880b...
# 1                           [57726f59edc2cb3880ba76b3]
# 2    [5772700eedc2cb3880bc82ce, 577278d5edc2cb3880d...
# 3    [57726e45edc2cb3880b69781, 577278d5edc2cb3880d...
# 4    [57727cbaedc2cb3880e561f7, 57727cbaedc2cb3880e...
# ..                                                 ...
# 168  [57727cbaedc2cb3880e561f7, 57727cbaedc2cb3880e...
# 169                         [57727cbaedc2cb3880e561f7]
# 170  [57726f59edc2cb3880ba76b3, 57726f59edc2cb3880b...
# 171  [577278d5edc2cb3880d94196, 57727015edc2cb3880b...
# 172  [5772700eedc2cb3880bc82ce, 577278d5edc2cb3880d...
#
#                                                  mixed
# 0    [5772700eedc2cb3880bc82ce, 5772700eedc2cb3880b...
# 1    [57726f59edc2cb3880ba76b3, 57726f59edc2cb3880b...
# 2                                                   []
# 3                                                   []
# 4    [57727cbaedc2cb3880e561f7, 57727015edc2cb3880b...
# ..                                                 ...
# 168                                                 []
# 169  [57727cbaedc2cb3880e561f7, 57727cbaedc2cb3880e...
# 170  [57726f59edc2cb3880ba76b3, 57726f59edc2cb3880b...
# 171  [5772700eedc2cb3880bc82ce, 5772700eedc2cb3880b...
# 172  [57726f4cedc2cb3880ba07ed, 57727c95edc2cb3880e...
#
# [173 rows x 7 columns]

# %%
for i in range(0, len(users_csv)):
  sim_list = []
  for j in range(0, len(users_csv)):
    sim = SimUsers.computeSimilarity(users_csv.loc(0)[i]['userId'], users_csv.loc(0)[j]['userId'])
    if sim >= 0:
      sim_list.append(sim)
    else:
      sim_list.append(0)
      
  users_matrix.append(sim_list)

# %%
users_sim = pd.DataFrame(users_matrix, index = [i for i in users_csv['userId']], columns = [i for i in users_csv['userId']])
users_sim.to_csv('data/Prado_users_explicador_similarity.csv')
